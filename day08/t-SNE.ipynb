# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.manifold import TSNE

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
iris = load_iris()

# %%
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
tsne = TSNE(n_components=2).fit_transform(df)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
tsne
# Out:
# array([[-20.345112 ,  10.0429125],
#        [-17.803696 ,  11.002795 ],
#        [-17.932014 ,   9.901397 ],
#        [-17.497683 ,  10.293139 ],
#        [-20.357115 ,  10.180324 ],
#        [-22.329445 ,  10.628629 ],
#        [-18.135872 ,   9.529462 ],
#        [-19.690525 ,  10.428024 ],
#        [-16.77427  ,  10.201678 ],
#        [-18.311255 ,  10.828579 ],
#        [-21.85141  ,   9.972688 ],
#        [-19.092615 ,  10.793221 ],
#        [-17.558727 ,  10.767473 ],
#        [-16.689589 ,   9.612383 ],
#        [-23.099026 ,   9.797674 ],
#        [-23.313057 ,  10.317648 ],
#        [-22.444864 ,  10.164583 ],
#        [-20.434736 ,  10.290708 ],
#        [-22.59654  ,   9.703831 ],
#        [-21.46457  ,  10.7184725],
#        [-21.253128 ,   9.393073 ],
#        [-21.13039  ,  10.753499 ],
#        [-18.367641 ,   8.734697 ],
#        [-20.057232 ,  11.457136 ],
#        [-19.187231 ,  11.677622 ],
#        [-18.224524 ,  11.393737 ],
#        [-19.96438  ,  11.039317 ],
# ...

# %%
tsne_df = pd.DataFrame(tsne, columns=['component0', 'component1'])

# %%
tsne_df
# Out:
#      component0  component1
# 0    -20.345112   10.042912
# 1    -17.803696   11.002795
# 2    -17.932014    9.901397
# 3    -17.497683   10.293139
# 4    -20.357115   10.180324
# ..          ...         ...
# 145   15.572321   -4.722122
# 146   12.478355   -4.316856
# 147   14.654025   -4.765091
# 148   15.974076   -4.046749
# 149   11.875330   -3.443748
#
# [150 rows x 2 columns]

# %% [markdown]
# ### t-sne 2차원 데이터 시각화

# %%
tsne_df['target'] = iris.target

# %%
tsne_df
# Out:
#      component0  component1  target
# 0    -20.345112   10.042912       0
# 1    -17.803696   11.002795       0
# 2    -17.932014    9.901397       0
# 3    -17.497683   10.293139       0
# 4    -20.357115   10.180324       0
# ..          ...         ...     ...
# 145   15.572321   -4.722122       2
# 146   12.478355   -4.316856       2
# 147   14.654025   -4.765091       2
# 148   15.974076   -4.046749       2
# 149   11.875330   -3.443748       2
#
# [150 rows x 3 columns]

# %%
tsne_df_0 = tsne_df[tsne_df['target']==0]
tsne_df_1 = tsne_df[tsne_df['target']==1]
tsne_df_2 = tsne_df[tsne_df['target']==2]

# %%
plt.scatter(tsne_df_0['component0'], tsne_df_0['component1'], color='pink', label='setosa')
plt.scatter(tsne_df_1['component0'], tsne_df_1['component1'], color='purple', label='versicolor')
plt.scatter(tsne_df_2['component0'], tsne_df_2['component1'], color='yellow', label='virginica')

plt.xlabel('component0')
plt.ylabel('component1')
plt.legend()
plt.show()

# %% [markdown]
# ### 3차원 t-sne 시각화

# %%
# t-sne 모델 불러오기
# 학습+변환->동시에
tsne = TSNE(n_components=3).fit_transform(df)

#데이터프레임 변환시킨 데이터 바꾸기 / 컬럼명: component0, component1, component2
tsne_df = pd.DataFrame(tsne, columns=['component0', 'component1', 'component2'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
tsne_df
# Out:
#      component0  component1  component2
# 0    -56.694450  -69.186813   15.806098
# 1    -67.673965 -121.330276   -3.260656
# 2    -83.541023   98.696609   63.564259
# 3    -62.513878   73.196068  137.782486
# 4   -105.946251  -55.092430   71.995987
# ..          ...         ...         ...
# 145  -62.963497  121.668854 -147.755371
# 146   92.861710   12.673221 -103.792831
# 147   53.375671  -59.068878   12.930730
# 148  156.056961   10.966164  -52.721153
# 149   80.328712   -9.996818  -56.557838
#
# [150 rows x 3 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D #3차원

# %%
tsne_df['target'] = iris.target

# %%
fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(111, projection='3d')

tsne_df_0 = tsne_df[tsne_df['target']==0]
tsne_df_1 = tsne_df[tsne_df['target']==1]
tsne_df_2 = tsne_df[tsne_df['target']==2]

ax.scatter(tsne_df_0['component0'], tsne_df_0['component1'], tsne_df_0['component2'], color='pink', label='setosa')
ax.scatter(tsne_df_1['component0'], tsne_df_1['component1'], tsne_df_1['component2'], color='purple', label='versicolor')
ax.scatter(tsne_df_2['component0'], tsne_df_2['component1'], tsne_df_2['component2'], color='yellow', label='virginia')

ax.set_xlabel('component0')
ax.set_ylabel('component1')
ax.set_zlabel('component2')
ax.legend()
plt.show()
