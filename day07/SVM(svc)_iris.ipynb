# %% [markdown]
# ### 1. 목적 : svc으로 iris 데이터 분류해보기

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC #분류

# %% [markdown]
# ### 2. 데이터 수집

# %%
df = load_iris()

# %%
x_data = pd.DataFrame(df.data, columns=df.feature_names)
y_data = pd.DataFrame(df.target, columns=['species'])

# %%
x_data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y_data.head()
# Out:
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### 3. 데이터 전처리
# - 스케일링

# %%
#1번-학습, 변환 순서로
scaler = MinMaxScaler()
scaler.fit(x_data)                #학습
x_data = scaler.transform(x_data) #변환

# %%
#2번-학습, 변환 동시에
scaler = MinMaxScaler()
scaler.fit_transform(x_data)
#1번과 2번은 같음(둘 중 하나 사용), 2번이 더 간단함

# %%
x_data
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
# scaler = MinMaxScaler()
# scaler.fit_transform(x_data)

# %%
#참고
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
#학습 데이터 스케일링 시

# %%
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)
#테스트 데이터 스케일링 시 여러줄 적어야하므로 2번째 방법이 더 간단함

# %% [markdown]
# ### 레이블 인코딩

# %%
le = LabelEncoder()
le.fit(y_data)
print(le.classes_)
# Out:
# [0 1 2]
# C:\Users\user\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
labels = ['세토사', '버시칼라', '버지니카']

# %%
y_data = le.transform(y_data)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.3, random_state=0, stratify=y_data)

# %% [markdown]
# ### 4. 탐색적 분석

# %% [markdown]
# ### 5-7. 모델링(생성, 학습, 평가)

# %%
model = SVC(kernel='rbf', gamma='auto', C=0.1, probability=True)

# %%
model.fit(x_train, y_train)
# Out:
# SVC(C=0.1, gamma='auto', probability=True)

# %%
model.score(x_train, y_train) #학습데이터 스코어
# Out:
# 0.9333333333333333

# %%
model.score(x_test, y_test) #테스트데이터 스코어
#gamma, C값 조정으로 과대적합 해소할 수 있음
# Out:
# 0.8666666666666667
